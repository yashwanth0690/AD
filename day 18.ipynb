# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import numpy as np

# %%
cars=pd.read_csv(r"C:\Users\yashw\Downloads\Cars.csv")
cars.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HP      81 non-null     int64
#  1   MPG     81 non-null     float64
#  2   VOL     81 non-null     int64
#  3   SP      81 non-null     float64
#  4   WT      81 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 3.3 KB

# %%
cars.sample(10)
# Out:
#      HP        MPG  VOL          SP         WT
# 19   90  38.901834  103  118.472936  33.516974
# 80  236  12.101263  107  139.840817  34.948615
# 30   84  39.431235  114  113.484609  37.042350
# 66  165  23.103172  114  132.484609  37.979956
# 56   96  31.113584   92  110.461264  30.147543
# 68  165  23.103172  123  133.312342  40.472042
# 67  165  23.103172  127  133.680223  41.573975
# 28   52  43.469434  104   99.564907  34.483207
# 18   78  42.789909   91  114.369293  29.929394
# 39  130  31.014131   92  128.461264  30.115434

# %%
cars.drop('HP',axis=1).corr()
# Out:
#           MPG       VOL        SP        WT
# MPG  1.000000 -0.529057 -0.687125 -0.526759
# VOL -0.529057  1.000000  0.102170  0.999203
# SP  -0.687125  0.102170  1.000000  0.102439
# WT  -0.526759  0.999203  0.102439  1.000000

# %%
cars.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
cars.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %%
cars.isna().sum()
# Out:
# HP     0
# MPG    0
# VOL    0
# SP     0
# WT     0
# dtype: int64

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.distplot(cars['MPG'])
# Out:
# <Axes: xlabel='MPG', ylabel='Density'>

# %%
sns.distplot(cars['HP'])
# Out:
# <Axes: xlabel='HP', ylabel='Density'>

# %%
sns.distplot(cars['VOL'])
# Out:
# <Axes: xlabel='VOL', ylabel='Density'>

# %%
sns.distplot(cars['SP'])
# Out:
# <Axes: xlabel='SP', ylabel='Density'>

# %%
sns.distplot(cars['WT'])
# Out:
# <Axes: xlabel='WT', ylabel='Density'>

# %%
sns.boxplot(cars['SP'])
# Out:
# <Axes: ylabel='SP'>

# %%
sns.boxplot(cars['WT'])
# Out:
# <Axes: ylabel='WT'>

# %%
import statsmodels.formula.api as smf
model = smf.ols("SP~WT",data = cars).fit()

# %%
sns.regplot(x="SP",y="WT",data=cars,ci=None);

# %%
cars.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
model.params
# Out:
# Intercept    115.256002
# WT             0.193884
# dtype: float64

# %%
sns.scatterplot(x=cars['MPG'],y=cars['VOL'],palette=['green','red'],hue=cars['HP'])
plt.show()

# %%
sns.scatterplot(x=cars['SP'], y=cars['MPG'])
# Out:
# <Axes: xlabel='SP', ylabel='MPG'>

# %%
sns.swarmplot(x=cars['VOL'],y=cars['WT'],palette=['yellow','red'],hue=cars['SP'])
# Out:
# <Axes: xlabel='VOL', ylabel='WT'>

# %%
cars.corr()
# Out:
#            HP       MPG       VOL        SP        WT
# HP   1.000000 -0.725038  0.077459  0.973848  0.076513
# MPG -0.725038  1.000000 -0.529057 -0.687125 -0.526759
# VOL  0.077459 -0.529057  1.000000  0.102170  0.999203
# SP   0.973848 -0.687125  0.102170  1.000000  0.102439
# WT   0.076513 -0.526759  0.999203  0.102439  1.000000

# %%
sns.heatmap(cars.corr(),cmap='Blues',annot=True)
plt.show()

# %%
sns.scatterplot(x=cars['HP'], y=cars['VOL'],color='green')
# Out:
# <Axes: xlabel='HP', ylabel='VOL'>

# %%
sns.scatterplot(x=cars['HP'], y=cars['SP'],color='black')
# Out:
# <Axes: xlabel='HP', ylabel='SP'>

# %%
sns.scatterplot(x=cars['VOL'], y=cars['SP'],color='purple')
# Out:
# <Axes: xlabel='VOL', ylabel='SP'>

# %%
sns.scatterplot(x=cars['VOL'], y=cars['WT'],color='darkorange')
# Out:
# <Axes: xlabel='VOL', ylabel='WT'>

# %%
sns.scatterplot(x=cars['SP'], y=cars['WT'],color='red')
# Out:
# <Axes: xlabel='SP', ylabel='WT'>
